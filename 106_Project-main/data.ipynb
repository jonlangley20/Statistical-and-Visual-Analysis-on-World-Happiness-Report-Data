# %%
# !pip install altair
# Out:
# Requirement already satisfied: altair in c:\users\maxym\anaconda3\lib\site-packages (4.1.0)
# Requirement already satisfied: entrypoints in c:\users\maxym\anaconda3\lib\site-packages (from altair) (0.3)
# Requirement already satisfied: pandas>=0.18 in c:\users\maxym\anaconda3\lib\site-packages (from altair) (1.0.5)
# Requirement already satisfied: jsonschema in c:\users\maxym\anaconda3\lib\site-packages (from altair) (3.2.0)
# Requirement already satisfied: toolz in c:\users\maxym\anaconda3\lib\site-packages (from altair) (0.10.0)
# Requirement already satisfied: numpy in c:\users\maxym\anaconda3\lib\site-packages (from altair) (1.18.5)
# Requirement already satisfied: jinja2 in c:\users\maxym\anaconda3\lib\site-packages (from altair) (2.11.2)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\maxym\anaconda3\lib\site-packages (from pandas>=0.18->altair) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in c:\users\maxym\anaconda3\lib\site-packages (from pandas>=0.18->altair) (2020.1)
# Requirement already satisfied: six>=1.11.0 in c:\users\maxym\anaconda3\lib\site-packages (from jsonschema->altair) (1.15.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\maxym\anaconda3\lib\site-packages (from jsonschema->altair) (0.16.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\maxym\anaconda3\lib\site-packages (from jsonschema->altair) (19.3.0)
# Requirement already satisfied: setuptools in c:\users\maxym\anaconda3\lib\site-packages (from jsonschema->altair) (49.2.0.post20200714)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\maxym\anaconda3\lib\site-packages (from jinja2->altair) (1.1.1)

# %%
import numpy as np
import os
import pandas as pd
import altair as alt
import matplotlib as plt

# %%
data = pd.read_csv('world-happiness-report.csv')
df = data.copy()
df['Regional indicator'] = df['Country name'].apply(find_region)
df = df.drop(columns = ['Positive affect','Negative affect'])
df
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008        3.724               7.370           0.451
# 1     Afghanistan  2009        4.402               7.540           0.552
# 2     Afghanistan  2010        4.758               7.647           0.539
# 3     Afghanistan  2011        3.832               7.620           0.521
# 4     Afghanistan  2012        3.783               7.705           0.521
# ...           ...   ...          ...                 ...             ...
# 1944     Zimbabwe  2016        3.735               7.984           0.768
# 1945     Zimbabwe  2017        3.638               8.016           0.754
# 1946     Zimbabwe  2018        3.616               8.049           0.775
# 1947     Zimbabwe  2019        2.694               7.950           0.759
# 1948     Zimbabwe  2020        3.160               7.829           0.717
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# 0                                50.80                         0.718
# 1                                51.20                         0.679
# 2                                51.60                         0.600
# 3                                51.92                         0.496
# 4                                52.24                         0.531
# ...                                ...                           ...
# 1944                             54.40                         0.733
# 1945                             55.00                         0.753
# 1946                             55.60                         0.763
# 1947                             56.20                         0.632
# 1948                             56.80                         0.643
#
#       Generosity  Perceptions of corruption  Regional indicator
# 0          0.168                      0.882          South Asia
# 1          0.190                      0.850          South Asia
# 2          0.121                      0.707          South Asia
# 3          0.162                      0.731          South Asia
# 4          0.236                      0.776          South Asia
# ...          ...                        ...                 ...
# 1944      -0.095                      0.724  Sub-Saharan Africa
# 1945      -0.098                      0.751  Sub-Saharan Africa
# 1946      -0.068                      0.844  Sub-Saharan Africa
# 1947      -0.064                      0.831  Sub-Saharan Africa
# 1948      -0.009                      0.789  Sub-Saharan Africa
#
# [1949 rows x 10 columns]

# %%
recent_data = pd.read_csv('world-happiness-report-2021.csv')
df2 = recent_data.copy()
df2['year'] = 2021
df2 = df2.drop(columns = ['Standard error of ladder score','upperwhisker','lowerwhisker','Ladder score in Dystopia',
                          'Explained by: Log GDP per capita','Explained by: Social support','Explained by: Healthy life expectancy',
                          'Explained by: Freedom to make life choices','Explained by: Generosity','Explained by: Perceptions of corruption',
                          'Dystopia + residual'])
df2 = df2.rename(columns = {'Ladder score':'Life Ladder','Logged GDP per capita':'Log GDP per capita',
                            'Healthy life expectancy':'Healthy life expectancy at birth'})
df2
# Out:
#     Country name  Regional indicator  Life Ladder  Log GDP per capita  \
# 0        Finland      Western Europe        7.842              10.775
# 1        Denmark      Western Europe        7.620              10.933
# 2    Switzerland      Western Europe        7.571              11.117
# 3        Iceland      Western Europe        7.554              10.878
# 4    Netherlands      Western Europe        7.464              10.932
# ..           ...                 ...          ...                 ...
# 144      Lesotho  Sub-Saharan Africa        3.512               7.926
# 145     Botswana  Sub-Saharan Africa        3.467               9.782
# 146       Rwanda  Sub-Saharan Africa        3.415               7.676
# 147     Zimbabwe  Sub-Saharan Africa        3.145               7.943
# 148  Afghanistan          South Asia        2.523               7.695
#
#      Social support  Healthy life expectancy at birth  \
# 0             0.954                            72.000
# 1             0.954                            72.700
# 2             0.942                            74.400
# 3             0.983                            73.000
# 4             0.942                            72.400
# ..              ...                               ...
# 144           0.787                            48.700
# 145           0.784                            59.269
# 146           0.552                            61.400
# 147           0.750                            56.201
# 148           0.463                            52.493
#
#      Freedom to make life choices  Generosity  Perceptions of corruption  year
# 0                           0.949      -0.098                      0.186  2021
# 1                           0.946       0.030                      0.179  2021
# 2                           0.919       0.025                      0.292  2021
# 3                           0.955       0.160                      0.673  2021
# 4                           0.913       0.175                      0.338  2021
# ..                            ...         ...                        ...   ...
# 144                         0.715      -0.131                      0.915  2021
# 145                         0.824      -0.246                      0.801  2021
# 146                         0.897       0.061                      0.167  2021
# 147                         0.677      -0.047                      0.821  2021
# 148                         0.382      -0.102                      0.924  2021
#
# [149 rows x 10 columns]

# %%
df.groupby('Country name').size()
# Out:
# Country name
# Afghanistan    12
# Albania        13
# Algeria         8
# Angola          4
# Argentina      15
#                ..
# Venezuela      15
# Vietnam        14
# Yemen          12
# Zambia         14
# Zimbabwe       15
# Length: 166, dtype: int64

# %%
dic = {}
for i in df2['Regional indicator'].unique():
    dic[i]=df2[df2['Regional indicator'] ==i].groupby('Country name').size().index
def find_region(x):
    for reg in dic.keys():
        for c in dic[reg]:
            if x == c:
                return reg

# %%
df['Regional indicator'] = df['Country name'].apply(find_region)

# %%
cmbd_df = pd.concat([df,df2])
cmbd_df
# Out:
#     Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0    Afghanistan  2008        3.724               7.370           0.451
# 1    Afghanistan  2009        4.402               7.540           0.552
# 2    Afghanistan  2010        4.758               7.647           0.539
# 3    Afghanistan  2011        3.832               7.620           0.521
# 4    Afghanistan  2012        3.783               7.705           0.521
# ..           ...   ...          ...                 ...             ...
# 144      Lesotho  2021        3.512               7.926           0.787
# 145     Botswana  2021        3.467               9.782           0.784
# 146       Rwanda  2021        3.415               7.676           0.552
# 147     Zimbabwe  2021        3.145               7.943           0.750
# 148  Afghanistan  2021        2.523               7.695           0.463
#
#      Healthy life expectancy at birth  Freedom to make life choices  \
# 0                              50.800                         0.718
# 1                              51.200                         0.679
# 2                              51.600                         0.600
# 3                              51.920                         0.496
# 4                              52.240                         0.531
# ..                                ...                           ...
# 144                            48.700                         0.715
# 145                            59.269                         0.824
# 146                            61.400                         0.897
# 147                            56.201                         0.677
# 148                            52.493                         0.382
#
#      Generosity  Perceptions of corruption  Regional indicator
# 0         0.168                      0.882          South Asia
# 1         0.190                      0.850          South Asia
# 2         0.121                      0.707          South Asia
# 3         0.162                      0.731          South Asia
# 4         0.236                      0.776          South Asia
# ..          ...                        ...                 ...
# 144      -0.131                      0.915  Sub-Saharan Africa
# 145      -0.246                      0.801  Sub-Saharan Africa
# 146       0.061                      0.167  Sub-Saharan Africa
# 147      -0.047                      0.821  Sub-Saharan Africa
# 148      -0.102                      0.924          South Asia
#
# [2098 rows x 10 columns]

# %%
cmbd_df.describe()
# Out:
#               year  Life Ladder  Log GDP per capita  Social support  \
# count  2098.000000  2098.000000         2062.000000     2085.000000
# mean   2013.768827     5.471402            9.373060        0.812709
# std       4.486449     1.112676            1.154247        0.118203
# min    2005.000000     2.375000            6.635000        0.290000
# 25%    2010.000000     4.652250            8.470500        0.750000
# 50%    2014.000000     5.392000            9.462000        0.835000
# 75%    2018.000000     6.282500           10.360750        0.905000
# max    2021.000000     8.019000           11.648000        0.987000
#
#        Healthy life expectancy at birth  Freedom to make life choices  \
# count                       2043.000000                   2066.000000
# mean                          63.478503                      0.746094
# std                            7.468780                      0.140766
# min                           32.300000                      0.258000
# 25%                           58.704500                      0.652000
# 50%                           65.280000                      0.767000
# 75%                           68.660000                      0.859000
# max                           77.100000                      0.985000
#
#         Generosity  Perceptions of corruption
# count  2009.000000                1988.000000
# mean     -0.001027                   0.745650
# std       0.161400                   0.186261
# min      -0.335000                   0.035000
# 25%      -0.115000                   0.688750
# 50%      -0.027000                   0.801000
# 75%       0.089000                   0.869000
# max       0.698000                   0.983000

# %%
cmbd_df.isnull().sum()
# Out:
# Country name                          0
# year                                  0
# Life Ladder                           0
# Log GDP per capita                   36
# Social support                       13
# Healthy life expectancy at birth     55
# Freedom to make life choices         32
# Generosity                           89
# Perceptions of corruption           110
# Regional indicator                   63
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Country name                          0
# year                                  0
# Life Ladder                           0
# Log GDP per capita                   36
# Social support                       13
# Healthy life expectancy at birth     55
# Freedom to make life choices         32
# Generosity                           89
# Perceptions of corruption           110
# Regional indicator                   63
# dtype: int64

# %%
df2.isnull().sum()
# Out:
# Country name                        0
# Regional indicator                  0
# Life Ladder                         0
# Log GDP per capita                  0
# Social support                      0
# Healthy life expectancy at birth    0
# Freedom to make life choices        0
# Generosity                          0
# Perceptions of corruption           0
# year                                0
# dtype: int64

# %%
x = 3.3333
round(x,2)
# Out:
# 3.33

# %%
x = 'ehoiseo. inoeisnfoi.a'
x.split('.')
# Out:
# ['ehoiseo', ' inoeisnfoi', 'a']

# %%
alt.Chart(cmbd_df[['year','Life Ladder']]).mark_line(x = 'year:Q',y='Life Ladder:Q')
# Out:
# ---------------------------------------------------------------------------
# SchemaValidationError                     Traceback (most recent call last)
# <ipython-input-105-6e10deb77c49> in <module>
# ----> 1 alt.Chart(cmbd_df[['year','Life Ladder']]).mark_line(x = 'year:Q',y='Life Ladder:Q')
#
# ~\anaconda3\lib\site-packages\altair\vegalite\v4\schema\mixins.py in mark_line(self, align, angle, aspect, baseline, binSpacing, blend, clip, color, cornerRadius, cornerRadiusBottomLeft, cornerRadiusBottomRight, cornerRadiusEnd, cornerRadiusTopLeft, cornerRadiusTopRight, cursor, dir, dx, dy, ellipsis, fill, fillOpacity, filled, font, fontSize, fontStyle, fontWeight, height, href, interpolate, invalid, limit, line, lineBreak, lineHeight, opacity, order, orient, point, radius, shape, size, stroke, strokeCap, strokeDash, strokeDashOffset, strokeJoin, strokeMiterLimit, strokeOffset, strokeOpacity, strokeWidth, style, tension, text, theta, thickness, timeUnitBand, timeUnitBandPosition, tooltip, width, x, x2, x2Offset, xOffset, y, y2, y2Offset, yOffset, **kwds)
#     148         copy = self.copy(deep=False)
#     149         if any(val is not Undefined for val in kwds.values()):
# --> 150             copy.mark = core.MarkDef(type="line", **kwds)
#     151         else:
#     152             copy.mark = "line"
#
# ~\anaconda3\lib\site-packages\altair\vegalite\v4\schema\core.py in __init__(self, type, align, angle, aspect, baseline, binSpacing, blend, clip, color, cornerRadius, cornerRadiusBottomLeft, cornerRadiusBottomRight, cornerRadiusEnd, cornerRadiusTopLeft, cornerRadiusTopRight, cursor, dir, dx, dy, ellipsis, fill, fillOpacity, filled, font, fontSize, fontStyle, fontWeight, height, href, interpolate, invalid, limit, line, lineBreak, lineHeight, opacity, order, orient, point, radius, shape, size, stroke, strokeCap, strokeDash, strokeDashOffset, strokeJoin, strokeMiterLimit, strokeOffset, strokeOpacity, strokeWidth, style, tension, text, theta, thickness, timeUnitBand, timeUnitBandPosition, tooltip, width, x, x2, x2Offset, xOffset, y, y2, y2Offset, yOffset, **kwds)
#   10010                  xOffset=Undefined, y=Undefined, y2=Undefined, y2Offset=Undefined, yOffset=Undefined,
#   10011                  **kwds):
# > 10012         super(MarkDef, self).__init__(type=type, align=align, angle=angle, aspect=aspect,
#   10013                                       baseline=baseline, binSpacing=binSpacing, blend=blend, clip=clip,
#   10014                                       color=color, cornerRadius=cornerRadius,
#
# ~\anaconda3\lib\site-packages\altair\vegalite\v4\schema\core.py in __init__(self, *args, **kwds)
#     105
#     106     def __init__(self, *args, **kwds):
# --> 107         super(AnyMark, self).__init__(*args, **kwds)
#     108
#     109
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in __init__(self, *args, **kwds)
#     174
#     175         if DEBUG_MODE and self._class_is_valid_at_instantiation:
# --> 176             self.to_dict(validate=True)
#     177
#     178     def copy(self, deep=True, ignore=()):
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in to_dict(self, validate, ignore, context)
#     337                 self.validate(result)
#     338             except jsonschema.ValidationError as err:
# --> 339                 raise SchemaValidationError(self, err)
#     340         return result
#     341
#
# SchemaValidationError: Invalid specification
#
#         altair.vegalite.v4.schema.core.MarkDef->0, validating 'type'
#
#         'year:Q' is not of type 'number'

# %%
dic = {.1:(1,3),.2:(4,6)}
for i in dic.keys():
    print(i)
    
list(dic.values())[0]
# Out:
# 0.1
# 0.2
# (1, 3)

# %%
def to_taxes(salary, tax_brackets):
    keys = list(tax_brackets.keys())
    values = list(tax_brackets.values())
    for bracket in tx_brackets.values():
        if bracket[0] < salary and bracket[1] > salary:
            return salary * keys[i]
